# %%
import requests
import pandas as pd

api_key = 'AIzaSyAvH7w8neoO0AaGrrP_-Pw9cN7bRujyBZw'
channel_id = 'UCKM0xzDyKUyJOJYGPUpmvlQ'

# Make a request to the YouTube API to get the channel information
url = f'https://www.googleapis.com/youtube/v3/channels?part=snippet,statistics&id={channel_id}&key={api_key}'
response = requests.get(url).json()

# Extract the relevant information from the API response
channel_title = response['items'][0]['snippet']['title']
subscriber_count = response['items'][0]['statistics']['subscriberCount']
view_count = response['items'][0]['statistics']['viewCount']
video_count = response['items'][0]['statistics']['videoCount']

# Create a dictionary with the extracted information
data = {'Channel Title': channel_title,
        'Subscriber Count': subscriber_count,
        'View Count': view_count,
        'Video Count': video_count}

# Create a pandas DataFrame with the extracted information
df = pd.DataFrame(data, index=[0])

# Save the DataFrame to a CSV file
df.to_csv('youtube_channel_data.csv', index=False)

# %%
print(df)
# Out:
#            Channel Title Subscriber Count View Count Video Count
# 0  Microsoft Power Tools             6710     441481         281

# %% [markdown]
# **To get a list of the recent uploads and add them to the dataframe**

# %%
# Make a request to the YouTube API to get the channel information
url = f'https://www.googleapis.com/youtube/v3/search?key={api_key}&channelId={channel_id}&part=snippet,id&order=date&maxResults=50'
response = requests.get(url).json()

video_titles = [item['snippet']['title'] for item in response['items']]
publish_dates = [item['snippet']['publishedAt'] for item in response['items']]

# Create an empty DataFrame with two columns
df = pd.DataFrame(columns=['Video Titles', 'Publish Dates'])

# Add the video titles and publish dates to the DataFrame
df['Video Titles'] = video_titles
df['Publish Dates'] = publish_dates

df
# Out:
#                                          Video Titles         Publish Dates
# 0                            Embrace Asking Questions  2023-01-26T11:59:54Z
# 1                             Learn SQL on Azure #sql  2023-01-06T09:09:43Z
# 2                             Microsoft Learn in 2023  2023-01-05T10:00:32Z
# 3   How to Deploy OnPremise Database to Azure SQL ...  2022-12-29T19:00:31Z
# 4       Rebuilding a Facility Maintenance Application  2022-12-17T23:25:09Z
# 5   Automate SQL Report Generation with Power Auto...  2022-12-07T11:29:27Z
# 6                    Post Bootcamp - What&#39;s Next?  2022-12-01T19:21:10Z
# 7   Create a Dataverse table for Facility Manageme...  2022-11-22T23:09:09Z
# 8                Build Your First App with Power Apps  2022-11-21T22:57:04Z
# 9   Redeemer&#39;s University Power Platform PreBo...  2022-11-20T17:49:33Z
# 10  Populate a MS SQL Database with Power Automate...  2022-11-19T08:37:43Z
# ...

# %%
import requests
import pandas as pd

# Set the API Key
API_Key = 'AIzaSyAvH7w8neoO0AaGrrP_-Pw9cN7bRujyBZw'

# Set the channel IDs
Channel_ids = ['UCnz-ZXXER4jOvuED5trXfEA', 'UCLLw7jmFsvfIVaUFsLs8mlQ',  'UCiT9RITQ9PW6BhXK0y2jaeg', 'UC7cs8q-gJRlGwj4A8OmCmXg', 'UC2UXDak6o7rBm23k3Vv5dww']

# Set the URL
url = "https://www.googleapis.com/youtube/v3/channels?part=snippet,statistics&id="

# Initialize lists to store data for each video
video_titles = []
publish_dates = []
likes = []
dislikes = []
channel_names = []
channel_id = []

# Loop through each channel ID
for id in Channel_ids:
    # Send the request and retrieve the response
    response = requests.get(url + id + "&key=" + API_Key).json()
    
    # Check if the response is valid
    if 'items' in response:
        # Get the channel name
        channel_name = response['items'][0]['snippet']['title']
        
        # Get the video information for each video
        videos_url = "https://www.googleapis.com/youtube/v3/search?part=snippet&channelId=" + id + "&key=" + API_Key + "&maxResults=50"
        videos_response = requests.get(videos_url).json()
        
        # Check if the response is valid
        if 'items' in videos_response:
            # Loop through each video in the response
            for item in videos_response['items']:
                # Get the video title and publish date
                video_title = item['snippet']['title']
                publish_date = item['snippet']['publishedAt']
                
                # Get the video statistics
                video_id = item['id']['videoId']
                stats_url = "https://www.googleapis.com/youtube/v3/videos?part=statistics&id=" + video_id + "&key=" + API_Key
                stats_response = requests.get(stats_url).json()
                
                # Check if the response is valid
                if 'items' in stats_response:
                    stats = stats_response['items'][0]['statistics']
                    
                    # Check if the 'likeCount' and 'dislikeCount' fields exist in the response
                    if 'likeCount' in stats:
                        like_count = stats['likeCount']
                    else:
                        like_count = None
                    
                    if 'dislikeCount' in stats:
                        dislike_count = stats['dislikeCount']
                    else:
                        dislike_count = None
